# %% [markdown]
# ![image.png](attachment:image.png)

# %%
avg_chairs_per_table = (0.05 * 0) + (.20 * 2) + (.60 * 4) + (1-.05-.2-.6)*6
print(f"Chairs to Manufacture: {avg_chairs_per_table} per Table")
# Out:
# Chairs to Manufacture: 3.7 per Table

# %%
table = 30
chair = 10
avg_profit_per_customer = .05*(table + 0*chair) + .2*(table + 2*chair) + .6*(table + 4*chair) + .15*(table + 6*chair)
print(f"Average Profit per Customer: ${round(avg_profit_per_customer, 2)}")
# Out:
# Average Profit per Customer: $67.0
